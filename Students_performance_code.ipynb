# %% [markdown]
# # Visualization and modelling of Students performance Exam dataset

# %%
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('StudentsPerformance.csv')
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# 13     male        group A                some college      standard
# 14   female        group A             master's degree      standard
# 15   female        group C            some high school      standard
# 16     male        group C                 high school      standard
# 17   female        group B            some high school  free/reduced
# 18     male        group C             master's degree  free/reduced
# 19   female        group C          associate's degree  free/reduced
# 20     male        group D                 high school      standard
# 21   female        group B                some college  free/reduced
# 22     male        group D                some college      standard
# 23   female        group C            some high school      standard
# 24     male        group D           bachelor's degree  free/reduced
# 25     male        group A             master's degree  free/reduced
# 26     male        group B                some college      standard
# 27   female        group C           bachelor's degree      standard
# 28     male        group C                 high school      standard
# 29   female        group D             master's degree      standard
# ..      ...            ...                         ...           ...
# 970  female        group D           bachelor's degree      standard
# 971    male        group C            some high school      standard
# 972  female        group A                 high school  free/reduced
# 973  female        group D                some college  free/reduced
# 974  female        group A                some college      standard
# 975  female        group C                some college      standard
# 976    male        group B                some college  free/reduced
# 977    male        group C          associate's degree      standard
# 978    male        group D                 high school      standard
# 979  female        group C          associate's degree      standard
# 980  female        group B                 high school  free/reduced
# 981    male        group D            some high school      standard
# 982    male        group B            some high school      standard
# 983  female        group A                some college      standard
# 984  female        group C            some high school      standard
# 985    male        group A                 high school      standard
# 986  female        group C          associate's degree      standard
# 987    male        group E            some high school      standard
# 988  female        group A            some high school  free/reduced
# 989  female        group D                some college  free/reduced
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# 5                      none          71             83             78
# 6                 completed          88             95             92
# 7                      none          40             43             39
# 8                 completed          64             64             67
# 9                      none          38             60             50
# 10                     none          58             54             52
# 11                     none          40             52             43
# 12                     none          65             81             73
# 13                completed          78             72             70
# 14                     none          50             53             58
# 15                     none          69             75             78
# 16                     none          88             89             86
# 17                     none          18             32             28
# 18                completed          46             42             46
# 19                     none          54             58             61
# 20                     none          66             69             63
# 21                completed          65             75             70
# 22                     none          44             54             53
# 23                     none          69             73             73
# 24                completed          74             71             80
# 25                     none          73             74             72
# 26                     none          69             54             55
# 27                     none          67             69             75
# 28                     none          70             70             65
# 29                     none          62             70             75
# ..                      ...         ...            ...            ...
# 970                    none          89            100            100
# 971               completed          78             72             69
# 972               completed          53             50             60
# 973                    none          49             65             61
# 974                    none          54             63             67
# 975               completed          64             82             77
# 976               completed          60             62             60
# 977                    none          62             65             58
# 978               completed          55             41             48
# 979                    none          91             95             94
# 980                    none           8             24             23
# 981                    none          81             78             78
# 982               completed          79             85             86
# 983               completed          78             87             91
# 984                    none          74             75             82
# 985                    none          57             51             54
# 986                    none          40             59             51
# 987               completed          81             75             76
# 988                    none          44             45             45
# 989               completed          67             86             83
# 990               completed          86             81             75
# 991               completed          65             82             78
# 992                    none          55             76             76
# 993                    none          62             72             74
# 994                    none          63             63             62
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# # Rename name of columns

# %%
df.columns=['gender','race','level_of_education','lunch','preparation','math','reading','writing']

# %% [markdown]
# # Add percentage column

# %%
df['percentage']=(df['math']+df['reading']+df['writing'])/3
df.head()
# Out:
#    gender     race  level_of_education         lunch preparation  math  \
# 0  female  group B   bachelor's degree      standard        none    72
# 1  female  group C        some college      standard   completed    69
# 2  female  group B     master's degree      standard        none    90
# 3    male  group A  associate's degree  free/reduced        none    47
# 4    male  group C        some college      standard        none    76
#
#    reading  writing  percentage
# 0       72       74   72.666667
# 1       90       88   82.333333
# 2       95       93   92.666667
# 3       57       44   49.333333
# 4       78       75   76.333333

# %%
# Check information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
# gender                1000 non-null object
# race                  1000 non-null object
# level_of_education    1000 non-null object
# lunch                 1000 non-null object
# preparation           1000 non-null object
# math                  1000 non-null int64
# reading               1000 non-null int64
# writing               1000 non-null int64
# percentage            1000 non-null float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 70.4+ KB

# %%
# Dataset doesn't contain null values

# %%
from matplotlib import pyplot as plt

#Check frequency of students with respect to gender

plt.bar('male',df.gender[df.gender=='male'].count())
plt.bar('female',df.gender[df.gender=='female'].count())
plt.ylabel("Number of Students")
_=plt.show()

# %% [markdown]
# # Add new column for grade

# %%
def For_assign_grade(percentage):      # Define funtion for assign grade of students
    if percentage>=90:
        return 'A'
    elif percentage>=80:
        return 'B'
    elif percentage>=70:
        return 'C'
    elif percentage>=60:
        return 'D'
    elif percentage>=50:
        return 'E'
    elif percentage>=40:
        return 'F'
    else:
        return 'FAIL'

df['grade']=df.percentage.apply(lambda x:For_assign_grade(x))
df.head()
# Out:
#    gender     race  level_of_education         lunch preparation  math  \
# 0  female  group B   bachelor's degree      standard        none    72
# 1  female  group C        some college      standard   completed    69
# 2  female  group B     master's degree      standard        none    90
# 3    male  group A  associate's degree  free/reduced        none    47
# 4    male  group C        some college      standard        none    76
#
#    reading  writing  percentage grade
# 0       72       74   72.666667     C
# 1       90       88   82.333333     B
# 2       95       93   92.666667     A
# 3       57       44   49.333333     F
# 4       78       75   76.333333     C

# %%
plt.bar('Pass',df.grade[df.grade!='FAIL'].count())
plt.bar('Fail',df.grade[df.grade=='FAIL'].count())
plt.ylabel('Number of Students')
plt.show()

# %%
# Number of Students who were fail in the exam are very less as compare to students who pass the exam

# %% [markdown]
# # Plot count of grading of students

# %%
plt.bar('Grade A',df.grade[df.grade=='A'].count())
plt.bar('Grade B',df.grade[df.grade=='B'].count())
plt.bar('Grade C',df.grade[df.grade=='C'].count())
plt.bar('Grade D',df.grade[df.grade=='D'].count())
plt.bar('Grade E',df.grade[df.grade=='E'].count())
plt.bar('Grade F',df.grade[df.grade=='F'].count())
plt.bar('Fail',df.grade[df.grade=='FAIL'].count())
plt.legend(['90-100','80-89','70-79','60-69','50-59','40-49','Fail'])
plt.show()

# %%
#We can see Grade C have the highest peak and Grade D have approx equal to Grade C

# %% [markdown]
# # Now we will see that how gender effect the grade of students

# %%
import seaborn as sns
p=sns.countplot(x='grade',data=df,hue='gender')
plt.xlabel('Grade')
# Out:
# Text(0.5,0,'Grade')

# %%
# In top three grades female dominate male in result

# %% [markdown]
# # Frequency of students from each group of race/ethinicity

# %%
p=sns.countplot(x='race',data=df,palette='bright')
_=plt.xlabel('Race / Ethinicity')

# %%
# Group C contain most number of students

# %% [markdown]
# # Now see the relation between race and grade of students

# %%
# All unique valeus in race column
df.race.unique()
# Out:
# array(['group B', 'group C', 'group A', 'group D', 'group E'],
#       dtype=object)

# %%
p=sns.countplot(x='race',data=df,hue='grade',palette='bright')
plt.xlabel('\nRace / Ethinicity')
# Out:
# Text(0.5,0,'\nRace / Ethinicity')

# %%
# Here Grade C and Grade D have higher peaks in every group except group A
# Group B contain more proportion of fail in exam as compare to other groups

# %% [markdown]
# # We will see that how parental level of education effect on their children grade

# %%
p=sns.countplot(x='level_of_education',data=df,hue='grade')
unused_variable=plt.setp(p.get_xticklabels(),rotation=330)
unused_variable=plt.xlabel('\nParental level of Education')

# %%
# All level of education contain approx equal peaks of grade A and grade D
# Failure of student happen more,when parental education is either high school or some high school
# Failure of student is NIL,if parental education is master's degree

# %%
# We see that race/ethinicty and parental level education affect differently on grade

# %% [markdown]
# # Now we will see the relation between level of eduacation and race/ethinicity

# %%
p=sns.countplot(x='race',data=df,hue='level_of_education',palette='bright')
unused_variale=plt.xlabel('Race / Ethinicity')
unused_variale=plt.legend(loc='upper right')

# %%
# In above graph ,high school and some high school contain nearly equal number of frequency.

# %% [markdown]
# # Relationship between preparation and grade of students

# %%
p=sns.countplot(x='grade',data=df,hue='preparation')
unused_variale=plt.xlabel('Parental level of Education')
unused_variale=plt.legend(loc='upper right')

# %% [markdown]
# # Now,We add one more column which signify wheather sudent is pass or fail

# %%
def result_status(grade):
    if grade=='FAIL':
        return 'FAIL'
    else:
        return 'PASS'
df['result']=df.grade.apply(lambda grade:result_status(grade))
df.head()
# Out:
#    gender     race  level_of_education         lunch preparation  math  \
# 0  female  group B   bachelor's degree      standard        none    72
# 1  female  group C        some college      standard   completed    69
# 2  female  group B     master's degree      standard        none    90
# 3    male  group A  associate's degree  free/reduced        none    47
# 4    male  group C        some college      standard        none    76
#
#    reading  writing  percentage grade result
# 0       72       74   72.666667     C   PASS
# 1       90       88   82.333333     B   PASS
# 2       95       93   92.666667     A   PASS
# 3       57       44   49.333333     F   PASS
# 4       78       75   76.333333     C   PASS

# %% [markdown]
# # Convert categorical data into numerical

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
df['gender']=lb.fit_transform(df['gender'])
df['race']=lb.fit_transform(df['race'])
df['level_of_education']=lb.fit_transform(df['level_of_education'])
df['lunch']=lb.fit_transform(df['lunch'])
df['preparation']=lb.fit_transform(df['preparation'])
df['grade']=lb.fit_transform(df['grade'])
df['result']=lb.fit_transform(df['result'])
df.head()
# Out:
#    gender  race  level_of_education  lunch  preparation  math  reading  \
# 0       0     1                   1      1            1    72       72
# 1       0     2                   4      1            0    69       90
# 2       0     1                   3      1            1    90       95
# 3       1     0                   0      0            1    47       57
# 4       1     2                   4      1            1    76       78
#
#    writing  percentage  grade  result
# 0       74   72.666667      2       1
# 1       88   82.333333      1       1
# 2       93   92.666667      0       1
# 3       44   49.333333      5       1
# 4       75   76.333333      2       1

# %% [markdown]
# # Correlation of dataset

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow0_col0 {
#             background-color:  #b40426;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow0_col1 {
#             background-color:  #6a8bef;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow0_col2 {
#             background-color:  #536edd;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow0_col3 {
#             background-color:  #88abfd;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow0_col4 {
#             background-color:  #86a9fc;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow0_col5 {
#             background-color:  #ebd3c6;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow0_col6 {
#             background-color:  #b3cdfb;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow0_col7 {
#             background-color:  #a9c6fd;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow0_col8 {
#             background-color:  #c9d7f0;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow0_col9 {
#             background-color:  #ebd3c6;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow0_col10 {
#             background-color:  #9dbdff;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow1_col0 {
#             background-color:  #85a8fc;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow1_col1 {
#             background-color:  #b40426;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow1_col2 {
#             background-color:  #4961d2;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow1_col3 {
#             background-color:  #8fb1fe;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow1_col4 {
#             background-color:  #84a7fc;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow1_col5 {
#             background-color:  #f0cdbb;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow1_col6 {
#             background-color:  #ebd3c6;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow1_col7 {
#             background-color:  #edd1c2;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow1_col8 {
#             background-color:  #f0cdbb;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow1_col9 {
#             background-color:  #c1d4f4;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow1_col10 {
#             background-color:  #a6c4fe;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow2_col0 {
#             background-color:  #86a9fc;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow2_col1 {
#             background-color:  #6282ea;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow2_col2 {
#             background-color:  #b40426;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow2_col3 {
#             background-color:  #84a7fc;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow2_col4 {
#             background-color:  #82a6fb;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow2_col5 {
#             background-color:  #cbd8ee;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow2_col6 {
#             background-color:  #cfdaea;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow2_col7 {
#             background-color:  #cdd9ec;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow2_col8 {
#             background-color:  #d1dae9;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow2_col9 {
#             background-color:  #e4d9d2;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow2_col10 {
#             background-color:  #8badfd;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow3_col0 {
#             background-color:  #8caffe;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow3_col1 {
#             background-color:  #799cf8;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow3_col2 {
#             background-color:  #5470de;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow3_col3 {
#             background-color:  #b40426;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow3_col4 {
#             background-color:  #8db0fe;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow3_col5 {
#             background-color:  #f7ba9f;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow3_col6 {
#             background-color:  #f2cab5;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow3_col7 {
#             background-color:  #f3c8b2;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow3_col8 {
#             background-color:  #f5c0a7;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow3_col9 {
#             background-color:  #afcafc;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow3_col10 {
#             background-color:  #c3d5f4;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow4_col0 {
#             background-color:  #85a8fc;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow4_col1 {
#             background-color:  #6687ed;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow4_col2 {
#             background-color:  #4b64d5;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow4_col3 {
#             background-color:  #86a9fc;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow4_col4 {
#             background-color:  #b40426;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow4_col5 {
#             background-color:  #b9d0f9;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow4_col6 {
#             background-color:  #b3cdfb;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow4_col7 {
#             background-color:  #a6c4fe;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow4_col8 {
#             background-color:  #b5cdfa;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow4_col9 {
#             background-color:  #f5c4ac;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow4_col10 {
#             background-color:  #84a7fc;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow5_col0 {
#             background-color:  #b3cdfb;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow5_col1 {
#             background-color:  #abc8fd;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow5_col2 {
#             background-color:  #3e51c5;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow5_col3 {
#             background-color:  #dbdcde;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow5_col4 {
#             background-color:  #5a78e4;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow5_col5 {
#             background-color:  #b40426;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow5_col6 {
#             background-color:  #d44e41;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow5_col7 {
#             background-color:  #d75445;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow5_col8 {
#             background-color:  #c32e31;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow5_col9 {
#             background-color:  #465ecf;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow5_col10 {
#             background-color:  #efcebd;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow6_col0 {
#             background-color:  #485fd1;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow6_col1 {
#             background-color:  #96b7ff;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow6_col2 {
#             background-color:  #3d50c3;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow6_col3 {
#             background-color:  #c0d4f5;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow6_col4 {
#             background-color:  #4a63d3;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow6_col5 {
#             background-color:  #d55042;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow6_col6 {
#             background-color:  #b40426;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow6_col7 {
#             background-color:  #bb1b2c;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow6_col8 {
#             background-color:  #b8122a;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow6_col9 {
#             background-color:  #3e51c5;
#         }    #T_9a851da8_542d_11e9_835b_d0c5d37e72ecrow6_col10 {

# %% [markdown]
# # Classification of Student result

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.cross_validation import train_test_split 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score

# %%
X=df.drop(['result'],axis=1)
Y=df['result']
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.3) 
#clf_entropy=DecisionTreeClassifier(criterion="gini",random_state=100) 

clf_entropy.fit(X_train,y_train)
y_pred=clf_entropy.predict(X_test)

# %%
("Accuracy score: ",(accuracy_score(y_test,y_pred)*100))
# Out:
# ('Accuracy score: ', 100.0)
